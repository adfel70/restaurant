# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from mpl_toolkits.basemap import Basemap
from geopy.geocoders import Bing

# %% [markdown]
# cottecting to mongoDB:

# %%
client = MongoClient("mongodb://localhost:27017/")
db = client["project1"]
restaurants_collection = db["Restaurants"]
people_collection = db["people"]

# %%
restaurants_data = pd.DataFrame(list(restaurants_collection.find()))
print(restaurants_data.head())
# Out:
#                         _id               Name       Street Address  \
# 0  647d9202a82a999427c5a8d8  Coach House Diner        55 State Rt 4
# 1  647d9202a82a999427c5a8d9   Table Talk Diner  2521 South Rd Ste C
# 2  647d9202a82a999427c5a8da        Sixty Vines     3701 Dallas Pkwy
# 3  647d9202a82a999427c5a8db       The Clam Bar    3914 Brewerton Rd
# 4  647d9202a82a999427c5a8dc        E Tutto Qua     270 Columbus Ave
#
#                        Location                                      Type  \
# 0     Hackensack, NJ 07601-6337      Diner, American, Vegetarian Friendly
# 1   Poughkeepsie, NY 12601-5476      American, Diner, Vegetarian Friendly
# 2          Plano, TX 75093-7777   American, Wine Bar, Vegetarian Friendly
# 3            Syracuse, NY 13212                    American, Bar, Seafood
# 4  San Francisco, CA 94133-4518                   Seafood, Italian, Pizza
#
#     Reviews No of Reviews                                           Comments  \
# 0  4.005882          85.0  Both times we were there very late, after 11 P...
# 1       4.0         256.0  Waitress was very friendly but a little pricey...
# 2       4.5         235.0  Not sure why I went there for the second time....
# 3       4.0         285.0  Doesn't look like much from the outside but wa...
# 4       4.5        1406.0
#
#     Contact Number                                        coordinates
# 0  +1 201-488-4999  {'type': 'Point', 'coordinates': [-74.032375, ...
# 1  +1 845-849-2839  {'type': 'Point', 'coordinates': [-73.931143, ...
# 2  +1 469-620-8463                                                NaN
# 3  +1 315-458-1662  {'type': 'Point', 'coordinates': [-76.141947, ...
# 4  +1 415-989-1002                                                NaN

# %%
restaurants_data['state'] = restaurants_data['Location'].str.split(',').str[-1].str.strip().str[:2]
restaurants_data['city'] = restaurants_data['Location'].str.split(',').str[0]

# %%
print(restaurants_data.dtypes)
print(restaurants_data.head())
# Out:
# _id               object
# Name              object
# Street Address    object
# Location          object
# Type              object
# Reviews           object
# No of Reviews     object
# Comments          object
# Contact Number    object
# coordinates       object
# state             object
# city              object
# dtype: object
#                         _id               Name       Street Address  \
# 0  647d9202a82a999427c5a8d8  Coach House Diner        55 State Rt 4
# 1  647d9202a82a999427c5a8d9   Table Talk Diner  2521 South Rd Ste C
# 2  647d9202a82a999427c5a8da        Sixty Vines     3701 Dallas Pkwy
# 3  647d9202a82a999427c5a8db       The Clam Bar    3914 Brewerton Rd
# 4  647d9202a82a999427c5a8dc        E Tutto Qua     270 Columbus Ave
#
#                        Location                                      Type  \
# 0     Hackensack, NJ 07601-6337      Diner, American, Vegetarian Friendly
# 1   Poughkeepsie, NY 12601-5476      American, Diner, Vegetarian Friendly
# 2          Plano, TX 75093-7777   American, Wine Bar, Vegetarian Friendly
# 3            Syracuse, NY 13212                    American, Bar, Seafood
# 4  San Francisco, CA 94133-4518                   Seafood, Italian, Pizza
#
#     Reviews No of Reviews                                           Comments  \
# 0  4.005882          85.0  Both times we were there very late, after 11 P...
# 1       4.0         256.0  Waitress was very friendly but a little pricey...
# 2       4.5         235.0  Not sure why I went there for the second time....
# 3       4.0         285.0  Doesn't look like much from the outside but wa...
# 4       4.5        1406.0
#
#     Contact Number                                        coordinates state  \
# 0  +1 201-488-4999  {'type': 'Point', 'coordinates': [-74.032375, ...    NJ
# 1  +1 845-849-2839  {'type': 'Point', 'coordinates': [-73.931143, ...    NY
# 2  +1 469-620-8463                                                NaN    TX
# 3  +1 315-458-1662  {'type': 'Point', 'coordinates': [-76.141947, ...    NY
# 4  +1 415-989-1002                                                NaN    CA
#
#             city
# 0     Hackensack
# 1   Poughkeepsie
# 2          Plano
# 3       Syracuse
# 4  San Francisco

# %%
restaurants_data['Reviews'] = pd.to_numeric(restaurants_data['Reviews'], errors='coerce')
restaurants_data['No of Reviews'] = pd.to_numeric(restaurants_data['No of Reviews'], errors='coerce')

# %%
filtered_df = restaurants_data[restaurants_data['Reviews'] > 4]
state_counts = filtered_df['state'].value_counts()
state_counts.plot(kind='bar', color = '#96C8A2')
plt.title('Number of restaurants with score over 4 by state')
plt.xlabel('State')
plt.ylabel('Number of restaurants')
plt.show()

# %%
people_data = pd.DataFrame(list(people_collection.find()))
print(people_data.head())
# Out:
#                         _id                name  \
# 0  647d921fbf78e94c8158a92b           Tom Hanks
# 1  647d921fbf78e94c8158a92c          Will Smith
# 2  647d921fbf78e94c8158a92d   Leonardo DiCaprio
# 3  647d921fbf78e94c8158a92e           Brad Pitt
# 4  647d921fbf78e94c8158a92f  Scarlett Johansson
#
#                                   restaurant_visited
# 0  [{'restaurant': 'Coach House Diner', 'score': ...
# 1  [{'restaurant': 'John Thomas Steakhouse', 'sco...
# 2  [{'restaurant': 'Revolve True Food & Wine Bar'...
# 3        [{'restaurant': 'Social 37', 'score': 4.0}]
# 4  [{'restaurant': 'Magic Castle', 'score': 5.0},...

# %%
types = restaurants_data['Type'].str.split(',').explode()
types = types.str.strip()
type_counts = types.value_counts()
top_15_types = type_counts.head(10)
other_types_count = type_counts[10:].sum()
top_15_types['Other'] = other_types_count

# Plot a pie chart of the types
colors = ['#B284BE', '#72A0C1', '#EFDECD', '#9F2B68', '#F19CBB', '#FFBF00', '#CD9575', '#FBCEB1', '#4B6F44', '#9F8170', '#2E5894', '#54626F', '#E97451', '#A3C1AD', '#FFFF99']
top_15_types.plot(kind='pie', autopct='%1.1f%%', colors=colors)
plt.title('Types of Restaurants')
plt.show()

# %%
plt.scatter(restaurants_data['No of Reviews'], restaurants_data['Reviews'], color = '#A2A2D0')
plt.title('Number of Reviews vs. Review Score')
plt.xlabel('state')
plt.ylabel('Review Score')
plt.show()

# %%
state_counts = filtered_df['Name'].value_counts().head(20)
state_counts.plot(kind='bar', color="#6699CC")
plt.title('Restaurants with most branches')
plt.xlabel('Restaurant')
plt.ylabel('Number of branches')
plt.show()

# %%
from geopy.exc import GeocoderTimedOut

data = restaurants_data[restaurants_data['Reviews'] == 5].copy()

geolocator = Bing(api_key='AhpwrCFQAHjj_6XelmahpGUxECXe1tonsrdoV2zAc9VJETqAj-6ekcmoMaKv5Ri6')

def geocode_with_timeout(location):
    try:
        return geolocator.geocode(location)
    except GeocoderTimedOut:
        return None

data.loc[:, 'address'] = data['Street Address'] + ", " + data['Location']
data.loc[:, 'new_location'] = data['address'].apply(geocode_with_timeout)
data.loc[:, 'Latitude'] = data['new_location'].apply(lambda x: x.latitude if x is not None else np.nan)
data.loc[:, 'Longitude'] = data['new_location'].apply(lambda x: x.longitude if x is not None else np.nan)

print(data.head())
# Out:
#                           _id                  Name         Street Address  \
# 29   647d9202a82a999427c5a8f5            Tabernilla  7124 Bob Bullock Loop
# 135  647d9202a82a999427c5a95f            Ambrogio15       926 Turquoise St
# 266  647d9202a82a999427c5a9e2            Very Juice           422 Avenue P
# 276  647d9202a82a999427c5a9ec  HiroNori Craft Ramen      2222 Michelson Dr
# 280  647d9202a82a999427c5a9f0        Bean's & Lager          3301 36th Ave
#
#                             Location                                   Type  \
# 29             Laredo, TX 78041-2080       Spanish, Mediterranean, Wine Bar
# 135         San Diego, CA 92109-1186               Italian, Pizza, Wine Bar
# 266          Brooklyn, NY 11223-1935
# 276            Irvine, CA 92612-1332   Japanese, Asian, Vegetarian Friendly
# 280  Long Island City, NY 11106-1941              American, Steakhouse, Bar
#
#      Reviews  No of Reviews  \
# 29       5.0           39.0
# 135      5.0          262.0
# 266      5.0            1.0
# 276      5.0           45.0
# 280      5.0           12.0
#
#                                               Comments   Contact Number  \
# 29   Unique tapas menu - NOT a Mexican restaurant! ...  +1 956-523-0989
# 135                                                     +1 858-291-8650
# 266  I travel a lot but couldn’t find better Peanut...  +1 718-676-9400
# 276                                                     +1 949-536-5800
# 280  Nothing Special. Visiting from out of town and...  +1 718-392-5777
#
#     coordinates state              city  \
# 29          NaN    TX            Laredo
# 135         NaN    CA         San Diego
# 266         NaN    NY          Brooklyn
# 276         NaN    CA            Irvine
# 280         NaN    NY  Long Island City
#
#                                             address  \
# 29     7124 Bob Bullock Loop, Laredo, TX 78041-2080
# 135      926 Turquoise St, San Diego, CA 92109-1186
# 266           422 Avenue P, Brooklyn, NY 11223-1935
# 276        2222 Michelson Dr, Irvine, CA 92612-1332
# 280  3301 36th Ave, Long Island City, NY 11106-1941
#
#                                           new_location   Latitude   Longitude
# 29   (7124 Bob Bullock Loop, Laredo, TX 78041, Unit...  27.560272  -99.444942
# 135  (926 Turquoise St, San Diego, CA 92109, United...  32.809441 -117.256957
# 266  (422 Avenue P, Brooklyn, NY 11223, United Stat...  40.608700  -73.971630
# 276  (2222 Michelson Dr, Irvine, CA 92612, United S...  33.676164 -117.855446
# 280  (3301 36th Ave, Queens, NY 11106, United State...  40.755889  -73.927833

# %% [markdown]
# ### Restaurants with score 5 on the USA map:
# Only score 5 because it was taking too long to find coordinates for all restaurants.

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1)

map = Basemap(projection='merc', llcrnrlat=20, urcrnrlat=50, llcrnrlon=-130, urcrnrlon=-60, resolution='l')

# Draw coastlines, countries, and states
map.drawcoastlines()
map.drawcountries()
map.drawstates()

# Convert latitude and longitude to map coordinates
x, y = map(data['Longitude'].astype(float), data['Latitude'].astype(float))

# Plot the points on the map
map.scatter(x, y, marker='o', color='red', zorder=5)

# Set a title for the plot
plt.title('Geographic Plot')

# Show the map
plt.show()

# %% [markdown]
# ### Restaurants with score 5 on the USA map:
# Only score 5 because it was taking too long to find coordinates for all restaurants.

# %%
import folium

# Create a map centered on the United States
map = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

for index, row in data.iterrows():
    if pd.notnull(row['Latitude']) and pd.notnull(row['Longitude']):
        # Add a marker for each location with available latitude and longitude
        folium.Marker(
            location=[row['Latitude'], row['Longitude']],
            popup=row['Name'],
            icon=folium.Icon(color='green', icon='info-sign')
        ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e603d2e1c535f72a3244bb4563c943b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e603d2e1c535f72a3244bb4563c943b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e603d2e1c535f72a3244bb4563c943b3 = L.map(
#                 &quot;map_e603d2e1c535f72a3244bb4563c943b3&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b87effe8903e0d97e559ea627e44f0bf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e603d2e1c535f72a3244bb4563c943b3);
#
#
#             var marker_a179bfcad730d66be9dd53782c8c9c2a = L.marker(
#                 [27.560272, -99.444942],
#                 {}
#             ).addTo(map_e603d2e1c535f72a3244bb4563c943b3);
#
#
#             var icon_06adf6548d65b56a78e86d9dc4eb41b8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a179bfcad730d66be9dd53782c8c9c2a.setIcon(icon_06adf6548d65b56a78e86d9dc4eb41b8);
#
#
#         var popup_23b3837fe7d7a6acfc65a0f8d5e4c67a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_63ac19e06d8ef4b906079fb9e62b7472 = $(`&lt;div id=&quot;html_63ac19e06d8ef4b906079fb9e62b7472&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tabernilla&lt;/div&gt;`)[0];
#                 popup_23b3837fe7d7a6acfc65a0f8d5e4c67a.setContent(html_63ac19e06d8ef4b906079fb9e62b7472);
#
#
#
#         marker_a179bfcad730d66be9dd53782c8c9c2a.bindPopup(popup_23b3837fe7d7a6acfc65a0f8d5e4c67a)
#         ;
#
#
#
#
#             var marker_67f149da1643db8e6e4e760a33109093 = L.marker(
#                 [32.809441, -117.256957],
#                 {}
#             ).addTo(map_e603d2e1c535f72a3244bb4563c943b3);
#
#
#             var icon_49d1ab7af5eb9daf244f755d7ca72adc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_67f149da1643db8e6e4e760a33109093.setIcon(icon_49d1ab7af5eb9daf244f755d7ca72adc);
#
#
#         var popup_a8b8ecd395738a14124e661e25d190cf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_37c9c9e4ee304e5ac1a916a29b4b84fe = $(`&lt;div id=&quot;html_37c9c9e4ee304e5ac1a916a29b4b84fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ambrogio15&lt;/div&gt;`)[0];
#                 popup_a8b8ecd395738a14124e661e25d190cf.setContent(html_37c9c9e4ee304e5ac1a916a29b4b84fe);
#
#
#
#         marker_67f149da1643db8e6e4e760a33109093.bindPopup(popup_a8b8ecd395738a14124e661e25d190cf)
#         ;
#
#
#
#
#             var marker_93cf6063c68380011ef59a22106994eb = L.marker(
#                 [40.6087, -73.97163],
#                 {}
#             ).addTo(map_e603d2e1c535f72a3244bb4563c943b3);
#
#
#             var icon_242abd5d73024e660dcd7fd302e9692d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_93cf6063c68380011ef59a22106994eb.setIcon(icon_242abd5d73024e660dcd7fd302e9692d);
#
#
#         var popup_46b22c30aa320d57368fb8ddcaa33874 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9e3355ecfbe1e27769bbf5afd2d7c656 = $(`&lt;div id=&quot;html_9e3355ecfbe1e27769bbf5afd2d7c656&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Very Juice&lt;/div&gt;`)[0];
#                 popup_46b22c30aa320d57368fb8ddcaa33874.setContent(html_9e3355ecfbe1e27769bbf5afd2d7c656);
#
#
#
#         marker_93cf6063c68380011ef59a22106994eb.bindPopup(popup_46b22c30aa320d57368fb8ddcaa33874)
#         ;
#
#
#
#
#             var marker_e15350332ef6fd2ff68a1068850223ca = L.marker(
#                 [33.676164, -117.855446],
#                 {}
#             ).addTo(map_e603d2e1c535f72a3244bb4563c943b3);
#
#
#             var icon_b1a530605ae3bab4c2808ca671cd9a54 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign
